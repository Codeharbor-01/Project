# %%
import pandas as pd

# %%
file_path = r"C:\Users\Asus\Desktop\Projects\Dataset\student_performance_dataset.csv"

df = pd.read_csv(file_path)

df.sample(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 778         779  Female               5.0               100.0          5.4
# 459         460    Male               4.2                74.7          5.5
# 95           96  Female               2.1                81.3          8.9
# 485         486  Female               2.3                82.9          7.4
# 729         730  Female               4.0                79.9          7.1
# 539         540  Female               1.2                75.8          7.1
# 966         967    Male               4.3                91.8          7.3
# 854         855    Male               2.9                86.1          6.8
# 929         930    Male               1.5                89.2          7.3
# 510         511    Male               3.2                82.4          4.3
#
#     parental_education internet_access extracurricular_activities  \
# 778                NaN             Yes                        Yes
# ...

# %%
df.isna().sum()
# Out:
# student_id                      0
# gender                          0
# study_time_hours                0
# attendance_percent              0
# sleep_hours                     0
# parental_education            102
# internet_access                 0
# extracurricular_activities      0
# part_time_job                   0
# previous_grade                  0
# final_exam_score                0
# final_grade                     0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    1000
# Name: count, dtype: int64

# %%
df['parental_education'] = df['parental_education'].ffill()

# %%
df.sample(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 494         495    Male               7.3                94.6          4.1
# 466         467  Female               2.5                73.1          5.5
# 694         695  Female               3.0                85.0          8.2
# 486         487    Male               1.4                81.9          4.3
# 778         779  Female               5.0               100.0          5.4
# 958         959  Female               4.9                63.5          5.6
# 499         500  Female               6.3                87.8          6.2
# 380         381  Female               3.4               100.0          6.8
# 335         336  Female               0.9                82.4          6.2
# 309         310  Female               3.0               100.0          8.5
#
#     parental_education internet_access extracurricular_activities  \
# 494          Bachelors             Yes                         No
# ...

# %%
df['parental_education'].value_counts()
# Out:
# parental_education
# High School    400
# Bachelors      335
# Masters        211
# PhD             54
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# student_id                      int64
# gender                            str
# study_time_hours              float64
# attendance_percent            float64
# sleep_hours                   float64
# parental_education                str
# internet_access                   str
# extracurricular_activities        str
# part_time_job                     str
# previous_grade                float64
# final_exam_score              float64
# final_grade                       str
# dtype: object

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'study_time_hours', 'attendance_percent',
#        'sleep_hours', 'parental_education', 'internet_access',
#        'extracurricular_activities', 'part_time_job', 'previous_grade',
#        'final_exam_score', 'final_grade'],
#       dtype='str')

# %%
df.sample(5)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 794         795    Male               3.8                83.1          8.0
# 349         350    Male               4.2                68.8          6.2
# 245         246  Female               5.8                76.5          7.4
# 241         242    Male               3.3                97.8          7.6
# 516         517  Female               3.5                96.7          6.1
#
#     parental_education internet_access extracurricular_activities  \
# 794        High School             Yes                         No
# 349            Masters             Yes                        Yes
# 245          Bachelors             Yes                        Yes
# 241        High School             Yes                         No
# 516        High School             Yes                         No
#
#     part_time_job  previous_grade  final_exam_score final_grade
# ...

# %%
mappings = {'Yes':True,'No':False}
df['internet_access'] = df['internet_access'].map(mappings)
df['extracurricular_activities'] = df['extracurricular_activities'].map(mappings)
df['part_time_job'] = df['part_time_job'].map(mappings)

# %%
df.sample(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 19           20    Male               4.4                77.4          8.4
# 3             4    Male               2.6                77.5          8.0
# 786         787    Male               3.7                81.8          5.2
# 545         546  Female               6.3                90.0          6.3
# 145         146    Male               1.0                67.3          5.7
# 391         392    Male               3.1                84.6          6.5
# 358         359    Male               4.3                75.7          3.8
# 171         172    Male               2.9                77.0          6.8
# 668         669    Male               2.7                71.5          8.9
# 600         601    Male               5.8                92.3          6.7
#
#     parental_education  internet_access  extracurricular_activities  \
# 19             Masters            False                       False
# ...

# %%
# df.to_csv('Dataset/cleaned_student_data.csv',index=False)

# %%
df['parental_education'].value_counts()
# Out:
# parental_education
# High School    400
# Bachelors      335
# Masters        211
# PhD             54
# Name: count, dtype: int64

# %%
df['final_grade'].value_counts()
# Out:
# final_grade
# B    354
# A    284
# C    261
# D     89
# F     12
# Name: count, dtype: int64
