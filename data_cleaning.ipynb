# %%
import pandas as pd

# %%
file_path = r"C:\Users\Asus\Desktop\Projects\Dataset\Student_data.csv"

df = pd.read_csv(file_path)

df.sample(10)
# Out:
#      Student_ID  Gender  Age             Major  Attendance_Pct  \
# 1612    ID01613    Male   18          Business            70.2
# 1220    ID01221  Female   24        Psychology            98.3
# 4572    ID04573    Male   24          Business            83.1
# 2766    ID02767    Male   24        Psychology            65.8
# 556     ID00557    Male   18          Business            77.0
# 439     ID00440    Male   19  Computer Science            86.6
# 932     ID00933  Female   23  Computer Science            80.5
# 4732    ID04733  Female   21        Psychology            86.6
# 3948    ID03949    Male   19         Economics            91.7
# 1304    ID01305  Female   19        Psychology            67.5
#
#       Study_Hours_Per_Day  Previous_CGPA  Sleep_Hours  Social_Hours_Week  \
# 1612                  5.2           3.63          7.5                  5
# 1220                  5.0           3.52          8.0                  6
# ...

# %%
df.isna().sum()
# Out:
# Student_ID             0
# Gender                 0
# Age                    0
# Major                  0
# Attendance_Pct         0
# Study_Hours_Per_Day    0
# Previous_CGPA          0
# Sleep_Hours            0
# Social_Hours_Week      0
# Final_CGPA             0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    5000
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#      Student_ID  Gender  Age        Major  Attendance_Pct  \
# 194     ID00195    Male   21  Mathematics            85.5
# 2318    ID02319    Male   21    Economics           100.0
# 267     ID00268  Female   21  Mathematics            91.3
# 506     ID00507  Female   18  Engineering            94.1
# 1497    ID01498    Male   23  Mathematics            68.1
# 366     ID00367  Female   24  Engineering            88.7
# 4696    ID04697    Male   20  Mathematics            69.9
# 50      ID00051  Female   18    Economics            71.0
# 2362    ID02363    Male   21    Economics           100.0
# 2092    ID02093    Male   23  Engineering            88.7
#
#       Study_Hours_Per_Day  Previous_CGPA  Sleep_Hours  Social_Hours_Week  \
# 194                   4.5           3.84          7.1                  5
# 2318                  4.8           3.43          5.7                  6
# 267                   7.3           3.50          5.3                 12
# ...

# %%
df.dtypes
# Out:
# Student_ID                 str
# Gender                     str
# Age                      int64
# Major                      str
# Attendance_Pct         float64
# Study_Hours_Per_Day    float64
# Previous_CGPA          float64
# Sleep_Hours            float64
# Social_Hours_Week        int64
# Final_CGPA             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Major', 'Attendance_Pct',
#        'Study_Hours_Per_Day', 'Previous_CGPA', 'Sleep_Hours',
#        'Social_Hours_Week', 'Final_CGPA'],
#       dtype='str')

# %%
df.sample(5)
# Out:
#      Student_ID  Gender  Age             Major  Attendance_Pct  \
# 2092    ID02093    Male   23       Engineering            88.7
# 270     ID00271  Female   24        Psychology           100.0
# 1498    ID01499    Male   21  Computer Science            78.2
# 2876    ID02877    Male   19          Business            72.3
# 526     ID00527    Male   21  Computer Science            99.6
#
#       Study_Hours_Per_Day  Previous_CGPA  Sleep_Hours  Social_Hours_Week  \
# 2092                  0.6           2.93          6.0                 11
# 270                   5.3           3.42          5.5                  5
# 1498                  1.5           3.77          8.0                  9
# 2876                  5.3           2.51          8.1                  2
# 526                   2.5           3.26          8.4                  8
#
#       Final_CGPA
# 2092        3.08
# 270         3.56
# 1498        3.87
# 2876        2.56
# 526         3.37

# %%
df.to_csv('Dataset/cleaned_student_data.csv',index=False)
