# %%
import pandas as pd

# %%
file_path = r"C:\Users\Asus\Desktop\Projects\Dataset\student_performance_dataset.csv"

df = pd.read_csv(file_path)

df.sample(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 204         205  Female               3.6                74.3          8.3
# 257         258  Female               1.2                89.5          6.0
# 115         116  Female               6.4                79.5          8.0
# 262         263    Male               3.2                96.9          6.8
# 646         647    Male               4.1                89.8          7.3
# 741         742  Female               2.4                96.1          8.4
# 4             5    Male               2.2                89.6          4.6
# 982         983  Female               2.8                73.8          7.3
# 836         837    Male               4.5                92.4          8.4
# 641         642  Female               3.7                97.4          7.3
#
#     parental_education internet_access extracurricular_activities  \
# 204            Masters             Yes                         No
# 257          Bachelors             Yes                        Yes
# 115            Masters              No                         No
# 262        High School              No                         No
# 646                NaN             Yes                        Yes
# 741          Bachelors             Yes                        Yes
# 4            Bachelors             Yes                         No
# 982        High School             Yes                         No
# 836          Bachelors             Yes                        Yes
# 641        High School             Yes                        Yes
#
#     part_time_job  previous_grade  final_exam_score final_grade
# 204            No            77.4              86.8           B
# 257           Yes            56.4              63.7           D
# 115           Yes            91.6              94.5           A
# 262            No            80.7              81.2           B
# 646            No            84.2             100.0           A
# 741            No            72.8              94.0           A
# 4             Yes            61.8              68.3           D
# 982           Yes            72.6              77.7           C
# 836           Yes            90.7             100.0           A
# 641            No            67.0              97.9           A

# %%
df.isna().sum()
# Out:
# student_id                      0
# gender                          0
# study_time_hours                0
# attendance_percent              0
# sleep_hours                     0
# parental_education            102
# internet_access                 0
# extracurricular_activities      0
# part_time_job                   0
# previous_grade                  0
# final_exam_score                0
# final_grade                     0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    1000
# Name: count, dtype: int64

# %%
df['parental_education'] = df['parental_education'].ffill()

# %%
df.sample(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 90           91  Female               4.4                83.8          6.5
# 924         925    Male               3.5                81.8          5.4
# 675         676    Male               0.5                83.6          6.4
# 393         394  Female               4.4                78.1          7.4
# 431         432  Female               4.8                77.8          7.2
# 229         230    Male               3.7               100.0          7.6
# 720         721  Female               4.4                76.0          5.2
# 419         420  Female               3.0                69.2          4.7
# 257         258  Female               1.2                89.5          6.0
# 12           13    Male               3.3                97.0          7.0
#
#     parental_education internet_access extracurricular_activities  \
# 90         High School             Yes                         No
# 924          Bachelors             Yes                        Yes
# 675        High School              No                        Yes
# 393        High School             Yes                        Yes
# 431        High School             Yes                        Yes
# 229        High School             Yes                        Yes
# 720        High School             Yes                        Yes
# 419          Bachelors              No                         No
# 257          Bachelors             Yes                        Yes
# 12             Masters             Yes                        Yes
#
#     part_time_job  previous_grade  final_exam_score final_grade
# 90             No            41.5              71.7           C
# 924            No            57.3              71.2           C
# 675           Yes            71.9              61.3           D
# 393            No            61.4              92.3           A
# 431            No            72.8             100.0           A
# 229           Yes            71.9              82.7           B
# 720            No            74.0              83.8           B
# 419            No            78.4              72.8           C
# 257           Yes            56.4              63.7           D
# 12            Yes            49.0              82.6           B

# %%
df['parental_education'].value_counts()
# Out:
# parental_education
# High School    400
# Bachelors      335
# Masters        211
# PhD             54
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# student_id                      int64
# gender                            str
# study_time_hours              float64
# attendance_percent            float64
# sleep_hours                   float64
# parental_education                str
# internet_access                   str
# extracurricular_activities        str
# part_time_job                     str
# previous_grade                float64
# final_exam_score              float64
# final_grade                       str
# dtype: object

# %%
df.columns
# Out:
# Index(['student_id', 'gender', 'study_time_hours', 'attendance_percent',
#        'sleep_hours', 'parental_education', 'internet_access',
#        'extracurricular_activities', 'part_time_job', 'previous_grade',
#        'final_exam_score', 'final_grade'],
#       dtype='str')

# %%
df.sample(5)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 844         845    Male               2.7                78.2          6.3
# 278         279    Male               2.4                98.0          7.4
# 362         363    Male               2.6                86.9          7.3
# 450         451  Female               5.8                73.6          9.1
# 850         851    Male               6.0                85.1          8.0
#
#     parental_education internet_access extracurricular_activities  \
# 844        High School             Yes                        Yes
# 278        High School             Yes                        Yes
# 362          Bachelors             Yes                        Yes
# 450            Masters              No                        Yes
# 850          Bachelors             Yes                         No
#
#     part_time_job  previous_grade  final_exam_score final_grade
# 844            No            75.6              80.2           B
# 278            No            65.5              94.0           A
# 362           Yes            55.1              66.7           D
# 450            No            54.2              77.9           C
# 850           Yes            81.2              99.5           A

# %%
mappings = {'Yes':True,'No':False}
df['internet_access'] = df['internet_access'].map(mappings)
df['extracurricular_activities'] = df['extracurricular_activities'].map(mappings)
df['part_time_job'] = df['part_time_job'].map(mappings)

# %%
df.sample(10)
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 105         106  Female               5.7               100.0          6.0
# 930         931    Male               1.9                93.4          6.7
# 219         220    Male               6.3                75.5          6.6
# 155         156  Female               1.8               100.0          5.3
# 239         240  Female               2.7                95.8          5.8
# 368         369    Male               2.1                90.1          6.7
# 331         332    Male               3.7                86.9          7.9
# 96           97  Female               1.1               100.0          9.2
# 70           71  Female               3.3                92.5          6.1
# 686         687  Female               3.6                85.9          7.0
#
#     parental_education  internet_access  extracurricular_activities  \
# 105            Masters             True                        True
# 930        High School             True                       False
# 219          Bachelors             True                       False
# 155          Bachelors             True                        True
# 239        High School             True                       False
# 368        High School            False                        True
# 331            Masters            False                        True
# 96           Bachelors             True                       False
# 70         High School             True                        True
# 686        High School             True                       False
#
#      part_time_job  previous_grade  final_exam_score final_grade
# 105           True            65.3              92.5           A
# 930          False            62.7              72.9           C
# 219          False            67.8             100.0           A
# 155          False            71.7              87.6           B
# 239           True            62.4              84.6           B
# 368          False            69.5              67.8           D
# 331          False            92.2              93.3           A
# 96            True            74.5              87.4           B
# 70           False            54.5              79.6           C
# 686          False            62.9              91.7           A

# %%
df.to_csv('Dataset/cleaned_student_data.csv',index=False)

# %%
df['parental_education'].value_counts()
# Out:
# parental_education
# High School    400
# Bachelors      335
# Masters        211
# PhD             54
# Name: count, dtype: int64

# %%
df['final_grade'].value_counts()
# Out:
# final_grade
# B    354
# A    284
# C    261
# D     89
# F     12
# Name: count, dtype: int64
